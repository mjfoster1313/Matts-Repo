# %% [markdown]
# <a href="https://colab.research.google.com/github/mjfoster1313/Matts-Repo/blob/main/Week6_HW5_Part_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.cluster import KMeans
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
iris_df = pd.DataFrame(iris.data, columns=iris.feature_names)
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
k_test = range(1,11)
wcss = []
for k in k_test:
    kmeans = KMeans(n_clusters=k, random_state=8, n_init="auto")
    kmeans.fit(iris.data)
    wcss.append(kmeans.inertia_)

# %%
plt.plot(k_test, wcss, 'bx-')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.title('Elbow Method For Optimal k')
plt.show()
